# %% [markdown]
# # 가상환경을 왜 쓰는가?
# - 독립적인 환경을 구성해주기 위해
# - 패키지끼리 버전 충돌을 막기 위해

# %%
import pandas as pd
pd.__version__
# Out:
# '1.0.5'

# %% [markdown]
# ### (상황 가정)
# 데이터 분석에 EDA를 빨리 해주고 싶은 니즈가 생김
# EDA패키지 dataprep.eda 패키지를 사용하려고 했으나 이 패키지를 사용하기 위해서 pandas 0.6버전을 사용해야 함
# 그러나 현재 사용하고 있고 굉장히 과거 버전과 다르게 1버전대는 성능과 편의성이 좋아졌음
# dataprep.eda 쓸 때 판다스 버전 잠깐 낮추고 다시 데이터 분석할 때 판다스 버전을 올렸다.
# 다른 패키지들끼리 버전충돌이 일어난다. 다시 패키지를 지웠다가 앞의 과정 반복한다.
# (어질어질)

# %% [markdown]
# [dataprep.eda둘러보기](https://eda-ai-lab.tistory.com/484)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (해결법)
# 둘 다 충돌없이 사용하기 위해서는 가상환경을 써야 한다!
# 하나는 dataprep.eda 패키지를 사용해야 하는 공간, 다른 하나는 현재와 마찬가지로 pandas 1.0버전대를 사용하는 것이다.

# %% [markdown]
# # 가상 환경 설정하기

# %% [markdown]
# 1. Window 사용자는 `명령프롬프트(CMD)-관리자권한`에서 Mac사용자는 `Terminal`에서 입력함
# 2. Yes/No 나오면 `y` 입력

# %% [markdown]
# - 가상 환경 생성
#
# conda create -n sba python=3.7

# %% [markdown]
# - 가상환경 활성화
#
# conda ?????? sba

# %% [markdown]
# - 패키지 설치
#
# conda install -c conda-forge notebook selenium matplotlib pandas numpy xmltodict folium==0.10.0 wordcloud

# %% [markdown]
# > pip install로 설치하면 패키지 많아지면 무조건 꼬인다.
# conda install로 설치하면 안정화된 패키지들 버전을 맞춰서 편리하게 설치해준다.
# 그러나 패키지의 최신버전을 사용하기는 어렵다.
# 그나마 conda-forge를 쓰면 조금 더 최신버전을 사용할 수 있다.
# [conda-forge를 써야하는 이유](https://17th-floor.tistory.com/11)

# %% [markdown]
# - 가상환경 리스트
#
# conda ?????? list

# %% [markdown]
# - 비활성화
#
# conda ??????

# %% [markdown]
# - 가상 환경을 제거
#
# conda remove -n {sba} --all

# %% [markdown]
# > 이제부터 수업 시작 전에
# `cmd/Terminal`에서 `conda activate sba` -> `jupyter notebook`

# %% [markdown]
# ---

# %% [markdown]
# - 코드 한 번에 실행시키기
#
# ```python
# conda create -n sba python=3.7 -y && conda activate sba && conda install -c conda-forge notebook selenium matplotlib pandas numpy xmltodict folium==0.10.0 wordcloud -y
# ```
