# %%
top100 = {'동두천자연휴양림':['경기',['산','캠핑','숲']],
            '한탄강주상절리길':['경기',['산책로','강','산']],
            '여강길' : ['경기',['산책로','산','숲']],
            '잣향기푸른숲' : ['경기',['산','숲','산책로']],
            '바람새마을 소풍정원' : ['경기',['캠핑','산책로','공원']],
            '평화누리공원': ['경기',['공원','체험학습']],
            '행주산성역사공원' : ['경기',['공원','산책로','강']],
            '갯골생태공원' : ['경기', ['공원','도심','체험학습']],
            '김포 평화누리길 1코스' : ['경기',['산책로','바다']],
            '곤지암 리조트 힐링캠퍼스' : ['경기',['산','산책로','체험학습','숲']],
            '호미반도해안둘레길':['경북',['산책로','바다']],
            '금오산 올레길' : ['경북',['산책로','강']],
            '경천대전망대' : ['경북',['산','강','체험학습','산책로']],
            '진남교반' : ['경북',['산','강','산책로']],
            '벌영리메타세콰이어길' : ['경북',['산책로','숲']],
            '낙강물길공원' : ['경북',['산책로','숲','공원']],
            '성밖숲' : ['경북',['도심','숲']],
            '국립백두대간수목원' : ['경북',['숲','체험학습','공원']],
            '등기산스카이워크' : ['경북',['바다','산책로']],
            '행남해안산책로' : ['경북',['산책로','바다']],
            '대청호 오백리길' : ['대전',['산책로','강']],
            '계족산 황톳길' : ['대전',['산책로','산']],
            '국립 대전현충원' : ['대전',['공원','체험학습']],
            '수통골' : ['대전',['산','강']],
            '장태산 자연휴양림' : ['대전',['산','숲','산책로']],
            '한밭수목원' : ['대전',['공원','도심','체험학습']],
            '만인산 자연휴양림':['대전',['산','산책로','체험학습']],
            '뿌리공원' : ['대전',['도심','공원','강','체험학습']],
            '상소동 산림욕장' : ['대전',['산','산책로']],
            '식장산 문화공원' : ['대전',['산','공원']],
            '장산' : ['부산',['도심','산']],
            '황령산' : ['부산',['도심','산']],
            '다대포해수욕장' :['부산',['도심','바다']],
            '천아숲길': ['제주', ['숲', '산책로', '산']],
            '무릉 자전거 도로': ['제주', ['산책로', '바다']],
            '정물오름': ['제주', ['산책로', '숲']],
            '논골담길': ['강원', ['산책로', '바다']],
            '의암호 자전거길': ['강원', ['산책로', '강']],
            '이사부길': ['강원', ['산책로', '바다', '공원']],
            '오대호아트팩토리': ['충청', ['체험학습']],
            '만뢰산자연생태공원': ['충청', ['산책로', '공원', '산']],
            '갈론계곡(갈론구곡)': ['충청', ['산', '캠핑']],
            '고복자연공원': ['충청', ['강', '산', '공원']],
            '조천연꽃공원': ['충청', ['공원', '산책로']],
            '운주산성': ['충청', ['산', '체험학습']],
            '웅도': ['충청', ['바다']],
            '칠갑산도립공원': ['충청', ['산책로', '공원', '산']],
            '예산황새공원': ['충청', ['공원']],
            '장수누리파크': ['전북', ['공원']],
            '교룡산국민관광지': ['전북', ['산', '체험학습']],
            '고신창포마을': ['전북', ['체험학습']],
            '펭귄마을': ['광주', ['도심', '체험학습']],
            '광주호호수생태원': ['광주', ['숲', '공원']],
            '시민의 숲 야영장': ['광주', ['숲', '캠핑']],
            '서산동 보리마당&시화마을': ['전남', ['도심', '바다']],
            '우수영': ['전남', ['바다', '공원']],
            '우주발사전망대': ['전남', ['바다', '체험학습']],
            '대운산 치유의 숲':['울산',['숲', '산책로']],
            '편백산림욕장': ['울산', ['산', '숲', '산책로']],
            '선암호수공원': ['울산', ['강', '공원']],
            '동촌유원지': ['대구', ['도심', '강', '공원']],
            '옥연지 송해공원': ['대구', ['공원', '바다']],
            '사문진 주막촌': ['대구', ['강', '공원', '체험학습']],
            '위양지(양양지)': ['경남', ['산책로', '공원']],
            '합천 대장경 테마파크': ['경남', '체험학습'],
            '김해 분청도자박물관': ['경남', ['도심', '체험학습']],
            '수선사': ['경남', ['강', '산']],
            '아미르공원':['부산', ['공원', '산책로', '도심']],
            '평화공원':['부산', ['강', '산책로', '도심']],
            '회동수원지':['부산', ['강', '산책로']],
            '치유의 숲':['부산', ['산', '숲', '산책로']],
            '구덕야영장':['부산', ['캠핑', '산', '숲']],
            '대저생태공원':['부산', ['공원', '강', '산책로']],
            '아차산':['서울', ['산', '산책로', '도심']],
            '배봉산':['서울', ['산', '산책로', '도심']],
            '북정마을':['서울', ['산책로', '산']],
            '안산':['서울', ['산', '도심', '산책로']],
            '돈의문박물관마을':['서울', ['체험학습', '도심']],
            '국립4.19민주묘지':['서울', ['숲', '공원', '체험학습']],
            '평화문화진지':['서울', ['체험학습','공원']],
            '서울함공원':['서울', ['공원', '강', '체험학습']],
            '양천향교':['서울', ['공원', '체험학습']],
            '서울 몽촌토성':['서울', ['공원', '산책로']],
            '교동도':['인천', ['바다', '체험학습']],
            '석모도':['인천', ['바다', '캠핑', '체험학습']],
            '동검도':['인천', ['바다', '캠핑']],
            '신도,시도,모도':['인천', ['바다', '공원', '산책로']],
            '굴업도':['인천', ['바다', '산책로']],
            '이작도':['인천', ['바다', '산책로']],
            '선녀바위':['인천', ['바다']],
            '송도 센트럴파크':['인천', ['강', '도심', '공원']],
            '계양산 둘레길':['인천', ['산', '도심', '산책로']],
            '경인 아라뱃길':['인천', ['강', '산책로']],
            '서건도':['제주', ['바다', '산책로']],
            '거문오름':['제주', ['산', '산책로']],
            '휴림':['제주', ['숲', '캠핑', '체험학습']],
            '물영아리 오름':['제주', ['산', '산책로']],
            '고살리 숲길':['제주', ['산책로', '산', '숲']],
            '신풍리 밭담길':['제주', ['산책로', '숲']],
            '북촌리4.3길':['제주', ['산책로', '체험학습']]}

# %%
# input
position = ["인천", "제주"]
category = ["산책로", "숲"]

# %%
import numpy as np

# %%
name= list(top100.keys())
point = list(top100.values())
do_name = np.array([point[i][0] for i in range(100)])
cate = [point[i][1] for i in range(100)]

# %%
ans = []
for i in position:
    for j in np.where(do_name == i)[0]:
        if category in cate[j]:
            ans.append(name[j])

# %%
ans
# Out:
# []
